# %%
 ## Importing random to use the random.choice and random.randint functions in the game.
    
import random

  ## Creating a prison_cell() function which will start the game upon user's discretion.##

def prison_cell():
    
  ## Two Print statements where first statement introduces the first scene of the movie and the second statement
  ## gives further information on the story of this game and then asks a question along with two options for 
  ## the user to choose from.##
    
    print(f"""\nWelcome to the first stage of the game. You are in your prison cell {name}, which is separate from 
others due to your bad repuatation of messing with other inmates. You have to escape the prison facility but 
first you must get out of your prison cell. You are locked up in a room around where there is one guard 
patrolling the place. The guard takes a round and then comes near your cell to check up on you.""")
          
    print(f"""\nToday is the day when all inmates are allowed to go for a shower in the toilet. Since you are kept separate 
and have a negative reputation, you will be accompanied by a guard. The guard has your prison keys. 
\nNow you have two options, either you can stealth attack the guard when he comes near to get the keys so that 
you can get out of your prison cell, and find a way out of the facility, or you can wait till you are taken to the 
toilet, and attack the guard then.
\nDo you want to:- 
- 1 = Stealth Attack the guard when he comes near
- 2 = Wait for being taken towards the toilet room""")
    
  ## A variable choice which takes and stores the user's input on the question above. ##  
    
    choice = input(prompt="\n> ") 
    choice = choice.lower()
    random_choice = random.randint(1,2)
    
  ## If statement which gives condition for both user's option and 
  ## tells the outcome in form of print statement. ##
    
  ## If choice includes 'stealth' or 'attack', then the user unfortunately fails the game and is directed back to the first stage 
  ## which is done by calling the prison_cell() function. ##
    
    if "stealth" in choice or "attack" in choice and random_choice == 1:
  
  ## A print statement which gives out the result of having 'stealth' or 'attack' in the option. ##
    
        print("\nYou tried to attack but the guard retaliated and other guards got allerted, \nGAME OVER!")
  
  ## Print statement which asks the user if they want to play again and gives two options where user can have
  ## 'play' or 'again' in choice or have 'quit' in choice. ##
        
        print(f"""\nDo you want to play again or quit the game?, {name}? """)
  
  ## Declaring a variable 'choice' which takes and stores the user's input. ##
  
        choice = input(prompt="\n> ")
    
  ## Using a lower() function which will take and store the user's input in lowercase ##

        choice = choice.lower()
    
  ## if statement for when user's input includes 'play' or 'again' in choice.
        
        if "play" in choice or "again" in choice:
            prison_cell()
            
  ## An elif statement which will be when the user chooses the second choice as their option and decides to leave. ##

        elif "quit" in choice:
            print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
            
            
  ## else statement for when the user input something other than the required input. 

  ## A while loop which will ask for user's input again if the user inputs something other the required input ##
    
        else: 
            while "play" not in choice and "quit" not in choice:
                print("\nSorry, Invalid input")
                print(f"""\nDo you want to play again or quit the game, {name}? """)
                choice = input(prompt="> ")
                choice = choice.lower()
                if "play" in choice:
                    prison_cell()
                elif "quit" in choice:
                    print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                else:
                    print("Try later")
    
    elif "wait" in choice or "toilet" in choice and random_choice == 2:
        
        
  ## A print statement which states the results and explains more of story and then asks another question when 
  ##the user's input has 'another' as their option for the question  ##
      
        print(f"""\nSmart move, {name}! you attacked the guard in the toilet where there are no cctv cameras.
Now you have to find a way out of the facility. In the washroom there is a pneumatic trash system which opens up
behind the prison ground from where all the trash is collected and taken out in a truck from the main gate. So, 
you now have to decide either take this risk or go out to find another way.
Here are your two options. \nSo {name} , what is it gonna be?:-
- 1 = Go through the trash system.
- 2 = Find another way out""")
 
  ## Declaring a variable 'choice' which takes and stores the user's input.
        
        choice = input(prompt="\n> ")
        
  ## Using a lower() function which will take and store the user's input in lowercase ##

        choice = choice.lower()
  
        random_choice = random.randint(1,2)
        
  ## If statement written when the user's input has 'trash' in their choice. 

        if "trash" in choice and random_choice == 1:
  
  ## A print statement which gives out the result of choosing the first choice as the option followed by giving out some more
  ## story to the user. ##
    
            print(f"""\nTrash it is! The path is not beautiful, the destination is even worse but the price is 
worth it, isn't it? :). \nNow you are out in the prison ground. The trash truck will come to the spot in one hour. 
Before that try to stay out of any trouble. \nGood luck!""")
  
  ## Calling out the 'prison_ground' funtion which will direct the user to the ground after the user inputs "1" as  
  ## their choice. ##
            
            prison_ground()
        
  ## An elif statement which will give the result when user inputs "2" as their choice which is a 'Game over' 
  ## statement since this is marked as an incorrect option. ## 

        elif "another" in choice:
            print("""\nHard luck, inmate! Prison guards were on a search for you and you are taken back to your 
cell and as a consequence, your imprisonment sentence has been increased. \nGAME OVER!""")
            
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
        
            print(f"""\nDo you want to play again or quit the game, {name}? """)
  
  ## Declaring a variable 'choice' which takes and stores the user's input. ##
  
            choice = input(prompt="\n> ")
    
  ## Using a lower() function which will take and store the user's input in lowercase ##

            choice = choice.lower()
    
  ## An if statement which is written for when the user decides to play again. 

            if "play" in choice:
        
  ## Calling the prison_cell function which will direct the user back to the start of the game. ##

                prison_cell()
  
  ## An elif statement which will be when the user chooses to quit ##
    
            elif "quit" in choice:
  
  ## A print statement which gives the output when user has 'quit' in their option. ##
    
                print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
  
  ## else statement for when the user input something other than the required input. 

  ## A while loop which will ask for user's input again if the user inputs something other the required input ##
    
            else: 
            
                while "play" not in choice and "quit" not in choice:
                   
                    print("\nSorry, Invalid input")
                    
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
    
                    print(f"""\nDo you want to play again or quit the game, {name}? """)
                    choice = input(prompt="\n> ")
                    choice = choice.lower()
                    if "play" in choice:
                        prison_cell()
                    elif "quit" in choice:
                        print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                    else:
                        print("Try later")
                        
  ## else statement for when the user input something other than the required input. 

  ## A while loop which will ask for user's input again if the user inputs something other the required input ##
                                   
    
        else:
            while "trash" not in choice and "another" not in choice:
                   
                    print("\nSorry, Invalid input")
                    print(f"""\nPlease try again, {name} """)
                    
   ## Declaring a variable 'choice' which takes and stores the user's input.

                    choice = input(prompt="\n> ")
                    
  ## Using a lower() function which will take and store the user's input in lowercase ##

                    choice = choice.lower()
                    if "trash" in choice:
                        print(f"""\nTrash it is! The path is not beautiful, the destination is even worse but the price is 
worth it, isn't it? :). \nNow you are out in the prison ground. The trash truck will come to the spot in one hour. 
Before that try to stay out of any trouble. \nGood luck!""")
                        prison_ground()
                    elif "another" in choice:
                        print("""\nHard luck, inmate! Prison guards were on a search for you and you are taken back to your 
cell and as a consequence, your imprisonment sentence has been increased. \nGAME OVER!""")
                    
                    else:
                         print("Try later")
                        
  ## If user inputs anything other than the required, then a print statement is 
  ## written in 'else' which says 'Sorry!, Invalid input' and 'Try again' ##
    
    else:
         while "stealth" not in choice and "attack" not in choice and "wait" not in choice and "toilet" not in choice:
                    
                    print("\nSorry, Invalid input")
                    print(f"""\nPlease try again, {name} """)
                    
  ## Declaring a variable 'choice' which takes and stores the user's input.
                    
                    choice = input(prompt="\n> ")
                    
  ## Using a lower() function which will take and store the user's input in lowercase ##

                    choice = choice.lower()
                    
                    if "stealth" in choice or "attack" in choice:
                        print("\nYou tried to attack but the guard retaliated and other guards got allerted, \nGAME OVER!")
                        prison_cell
                    elif "wait" in choice or "toilet" in choice:
                        print(f"""\nSmart move, {name}! you attacked the guard in the toilet where there are no cctv cameras.
Now you have to find a way out of the facility. In the washroom there is a pneumatic trash system which opens up
behind the prison ground from where all the trash is collected and taken out in a truck from the main gate. So, 
you now have to decide either take this risk or go out to find another way.
Here are your two options. \nSo {name} , what is it gonna be?:-
- 1 = Go through the trash system.
- 2 = Find another way out""")
                        
  ## Declaring a variable 'choice' which takes and stores the user's input.
                        
                        choice = input(prompt="\n> ")
         
                        random_choice = random.randint(1,2)
        
  ## Using a lower() function which will take and store the user's input in lowercase ##

                        choice = choice.lower()
            
                        if "trash" in choice and random_choice == 1:
                            print(f"""\nTrash it is! The path is not beautiful, the destination is even worse but the price is 
worth it, isn't it? :). \nNow you are out in the prison ground. The trash truck will come to the spot in one hour. 
Before that try to stay out of any trouble. \nGood luck!""")
                            prison_ground()
                        elif "another" in choice and random_choice == 2:
                            print("""\nHard luck, inmate! Prison guards were on a search for you and you are taken back to your 
cell and as a consequence, your imprisonment sentence has been increased. \nGAME OVER!""")
                            print(f"""\nDo you want to play again or quit the game, {name}? """)
                            
  ## Declaring a variable 'choice' which takes and stores the user's input. ##

                            choice = input(prompt="\n> ")
                            
  ## Using a lower() function which will take and store the user's input in lowercase ##

                            choice = choice.lower()
                            if "play" in choice:
                                prison_cell()
  
                            elif "quit" in choice:
                                print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
            
  ## else statement for when the user input something other than the required input. 

  ## A while loop which will ask for user's input again if the user inputs something other the required input ##
    
                            else: 
                                while "play" not in choice and "quit" not in choice:
                                    print("\nSorry, Invalid input")
                        
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
    
                                    print(f"""\nDo you want to play again or quit the game, {name}? """)
                            
  ## Declaring a variable 'choice' which takes and stores the user's input. ##

                                    choice = input(prompt="\n> ")
                                
  ## Using a lower() function which will take and store the user's input in lowercase ##

                                    choice = choice.lower()
                                    if "play" in choice:
                                        prison_cell()
                                    elif "quit" in choice:
                                        print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                                    else:
                                        print("Try later")

  ## Defining a function called "prison_ground" which is the second stage of the game.

def prison_ground(): 
  
  ## A print statement which introduces the second stage of the game and gives more story followed by asking a
  ## a question and giving two options for the user to choose from. ##

    print(f"""\nThis is the second stage of the game. \nYou are in the ground. While walking, you accidently bumped into another
prisoner who was apparently having a not too good of a day and now he wants to have a fight.
\nTold you before not to get into trouble but that is not possible for someone like you, is it? \nNow you have to get out of this as soon as you can since the truck can be your one and only way out. 
So {name}, you can either fight back since you are known for that or take the easy way out which is to run away. 
What is it gonna be {name}?
Please type in your answer.
- 1 = Fight back 
- 2 = Run away """) 
    
  ## Declaring a variable 'choice' which takes and stores the user's input. ##
    
    choice = input(prompt="\n> ")
    choice = choice.lower()
    
    random_choice = random.randint(1,2)
    
  ## An if statement which gives conditions on the user's input and then gives the output.

    if "fight" in choice and random_choice == 1:
  
  ## A print statement which gives the output statement for when the user's input has 'fight' in their choice
  ## which in turn becomes a 'Game over' statement since this is an incorrect choice. ##
    
        print("""\nOh, too much about the image han? So, you started fighting and a thousand people gathered which 
caught the prison guards attention and you are taken back to your cell. Home Sweet Home! \nGAME OVER!""")
        
  ## Print statement which asks the user if they want to play again and gives options to select from. ##
        
        print(f"""\nDo you want to play again or quit the game, {name}? """)
        
  ## Declaring a variable 'choice' which takes and stores the user's input. ##

        choice = input(prompt="\n> ")
        ''
  ## Using a lower() function which will take and store the user's input in lowercase ##

        choice = choice.lower()
        if "play" in choice:
            prison_cell()
        elif "quit" in choice:
            print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
        else: 
            while "play" not in choice and "quit" not in choice:
                print("\nSorry, Invalid input")
                
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
    
                print(f"""\nDo you want to play again or quit the game, {name}? """)
                choice = input(prompt="\n> ")
                
  ## Using a lower() function which will take and store the user's input in lowercase ##

                choice = choice.lower()
                if "play" in choice:
                    prison_cell()
                elif "quit" in choice:
                    print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                else:
                    print("Try later")
                                  
  
  ## An elif statement which will display the outcome if the user chooses the second choice as their answer. ##
    
    elif "run" in choice and random_choice == 2:
    
  ## A print statement which will give out the results when the user selects the second choice of answer.

        print("""You ran away and got yourself saved from a lot of mess. SEE!, not so bad of a choice afterall. 
Now, find the trash truck and be a part of the waste before all your effort goes to waste.""")
        trash_truck()
        
  ## An else statement which will display the output when the user inputs anything other than the required.

    else:
        while "fight" not in choice and "run" not in choice:
                   
                    print("\nSorry, Invalid input")
                    print(f"""\nPlease try again, {name} """)
                    choice = input(prompt="\n> ")
                    
  ## Using a lower() function which will take and store the user's input in lowercase ##

                    choice = choice.lower()
                    if "fight" in choice:
                        print("""\nOh, too much about the image han? So, you started fighting and a thousand people gathered which 
caught the prison guards attention and you are taken back to your cell. Home Sweet Home! \nGAME OVER!""")
                    elif "run" in choice:
                        print("""You ran away and got yourself saved from a lot of mess. SEE!, not so bad of a choice afterall. 
Now, find the trash truck and be a part of the waste before all your effort goes to waste.""")
                        trash_truck()
                    else:
                         print("Try later")
                    
  ## Constructing and defining a function called the 'trash truck' which is the third and last stage of the game. ##

def trash_truck():
  
  ## A print statement which introduces the final stage of the game followed by some story and then asks a 
  ## question with two options to choose from which leads onto the finale of the game. ##

    print(f"""\nThis is the third and final stage of the game. \nYou are now in search of the truck and suddenly
see a truck entering from the main gate. The truck driver will park the truck near the garbage disposal and then 
go for signing a form at the office which shows his presence here. Remember, you have to get at the back of the 
truck since you are not driving, or are you? Hmm, looks like now we have two options again which are first being 
that you can either attack the guard and make him unconscious so that you can wear his attire and leave the prison 
by driving the truck out of the prison or you can try to fit at the back of the truck and then automatically be 
thrown out of the truck when it disposes off the trash which is at the landfill located 2kms from the 
prison facility. 
What has it got to be {name }?
- 1 =Disguise as the driver
- 2 = Try fitting under the waste in the back of the trash truck.
\nPlease type in your answer""")
    
  ## Declaring a variable 'choice' which takes and stores the user's input. ##
    
    choice = input(prompt="\n> ")
  
  ## Using a lower() function which will take and store the user's input in lowercase ##
    
    choice = choice.lower()
    
  ## An if statement which gives conditions on the user's input includes 'disguise' or 'driver' 
  ## and then gives the output. ##

    if "disguise" in choice or "driver" in choice and random_choice == 1:
    
  ## Print statement which gives the output when the user selects the first choice which turns out to be the
  ## wrong option and the user is taken back to the cell ##
        
        print(f"""Oops! You can DRESS the same but not LOOK the same. The prison security at the gate 
recognized it was not you who came in and you got caught. Too bad, Back to the pavillion. \nGAME OVER! """)
        
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
        
        print(f"""\nDo you want to play again or quit the game, {name}? """)
        choice = input(prompt="\n> ")
        
  ## Using a lower() function which will take and store the user's input in lowercase ##

        choice = choice.lower()
        if "play" in choice:
            prison_cell()
        elif "quit" in choice:
            print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
        else: 
            while "play" not in choice and "quit" not in choice:
                print("\nSorry, Invalid input")
                print(f"""\nDo you want to play again or quit the game, {name}? """)
                choice = input(prompt="\n> ")
                
    ## Using a lower() function which will take and store the user's input in lowercase ##
    
                choice = choice.lower()
                if "play" in choice:
                    prison_cell()
                elif "quit" in choice:
                    print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                else:
                    print("Try later")
                                  
  ## If the user selects the second option, then the print statement gives the outcome and 
  ## then proceeds with the game by asking the user to type an option from the two given in the statement. ## 
    
    elif "under the waste" in choice or "truck" in choice and random_choice == 2:
        
  ## A print statement which will display the output when the user selects the second option with 
  ## 'under the waste' or 'truck' in the choice. ##
    
        print("""Looks like this is the only way out. Good choice! You hid yourself like your life depended on 
it, cause it actually did. The truck did not get checked and you have successfully managed to escape from the 
prison with your great Escape Plan.\n YOU WIN!!! """)
        
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
        
        print(f"""\nDo you want to play again or quit the game, {name}? """)
        choice = input(prompt="\n> ")
        
  ## Using a lower() function which will take and store the user's input in lowercase ##

        choice = choice.lower()
        if "play" in choice or "again" in choice:
            prison_cell()
        elif "quit" in choice:
            print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
        else: 
            while "play" not in choice and "quit" not in choice:
                print("\nSorry, Invalid input")
                print(f"""\nDo you want to play again or quit the game, {name}? """)
                choice = input(prompt="\n> ")
                
  ## Using a lower() function which will take and store the user's input in lowercase ##

                choice = choice.lower()
                if "play" in choice:
                    prison_cell()
                elif "quit" in choice:
                    print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                else:
                     print("Try later")
                                  
           
  ## An else statement which is when the user inputs anything other than required as their answer. ## 
        
    else:
         while "disguise" not in choice or "driver" not in choice or "under the waste" not in choice or "truck" not in choice:
                   
            print("\nSorry, Invalid input")
            print(f"""\nPlease try again, {name} """)
            choice = input(prompt="\n> ")
            
  ## Using a lower() function which will take and store the user's input in lowercase ##

            choice = choice.lower()
            if "disguise" in choice or "attack" not in choice:
                print(f"""Oops! You can DRESS the same but not LOOK the same. The prison security at the gate 
recognized it was not you who came in and you got caught. Too bad, Back to the pavillion. \nGAME OVER! """)
                
  ## Print statement which asks the user if they want to play again or quit and gives choice and options
  ## to select from. ##
        
                print(f"""\nDo you want to play again or quit the game, {name}? """)
                choice = input(prompt="\n> ")
                
  ## Using a lower() function which will take and store the user's input in lowercase ##

                choice = choice.lower()
                if "play" in choice:
                    prison_cell()
                elif "quit" in choice:
                    print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                else: 
                    while "play" not in choice and "quit" not in choice:
                        print("\nSorry, Invalid input")
                        print(f"""\nDo you want to play again or quit the game, {name}? """)
                        choice = input(prompt="\n> ")
                        
  ## Using a lower() function which will take and store the user's input in lowercase ##

                        choice = choice.lower()
                        if "play" in choice:
                            prison_cell()
                        elif "quit" in choice:
                            print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
                        else:
                            print("Try later")
                            
            elif "under the waste" in choice or "truck" not in choice:
                
                print("""Looks like this is the only way out. Good choice! You hid yourself like your life depended on 
it, cause it actually did. The truck did not get checked and you have successfully managed to escape from the 
prison with your great Escape Plan.\n YOU WIN!!! """)
                    
            else:
                print("Try later")


## Creating a list by the name of prison_location which has 10 different locations of countries ##
 
prison_location = ['U.S.A','U.K','GERMANY','RUSSIA','FRANCE','BRAZIL','ITALY','CHINA','CANADA','INDIA']
    
 ## Creating two different lists namely answer_yes and answer_no which has 'y' and 'n' as elements for taking the u
 ## user's input. ##
    
answer_yes = "y"
answer_no = "n"

  ## Declaring a variable 'answer' which recieves and stores the user's 
  ## answer to the 'Do you want to start the game?' question. ##

answer = ""

  ## Declaring a variable 'name' which recieves and stores the 
  ## user's input on the 'What's your name ?' question.##

name = "" 

  ## A while loop which starts the introduction again when user inputs 
  ## anything other than the input options in answer_yes.##

while answer != (answer_yes): 
    
  ## A print statement along with 'prompt' which will ask for the user's name and store it in the variable name ##
  ## Assigning the variable 'name' to the input function. ##
    
    name = input(prompt="\nWhat's your name?\n> ")
    
  ## Put a capitalize formula which will take the user's input and capitalize only the first letter of the name ##

    name = name.capitalize()
    
  ## A print statement which welcomes the user ##
    
    print(f"""\nHello {name}! :)""")
    print("//////////////////////////////////////////////" )
    print("//////////////////////////////////////////////" )
    print("////// WELCOME TO THE ESCAPE PLAN GAME ///////")
    print("//////////////////////////////////////////////" )
    print("//////////////////////////////////////////////" )
    
  ## A random variable which will select on random an element from the list 'prison_location' ##

    location = random.choice(prison_location)
    
  ## A print statement which will introduce the game and give a little story and explain the instructions ##
    
    print(f"""\nThis is the Escape Plan game, {name} !, you are a prisoner locked up in the most toughest prison of {location}. 
You have to complete the game by escaping the prison. If you get caught by guard or do something which gains attention, then you will loose the game. 
In each step you will be asked questions and you have to choose one of the two options to proceed in the game. 
If it is the correct option, you will move ahead, otherwise, the game will be over.""") 
    
  ## Print statement along with 'prompt' which will ask the user whether they want to start the game or not.##

  ## Assigning the variable 'answer' to the input function. ##
    
    answer = input(prompt="\nDo you want to start the game? \n > ")
    
  ## using a lower function which will take the user's input and store as lowercase ##

    answer = answer.lower()
   
  ## If statement which gives condition on if the user input is in the 'answer_yes' list.
    
    if answer_yes in answer:
        
  ## Calling the prison_cell function which will take the user to the first stage of the game. ##

        prison_cell() 
    
  ## elif statement which will display output if the user's input is in the 'answer_no' list. ##

    elif answer_no in answer:
        
  ## Print statement which shows output if the user does not want to play the game. 

        print(f"Okay, Goodbye {name} !") 
    
  ## else statement for when the user input something other than the required input. 

  ## A while loop which will ask for user's input again if the user inputs something other the required input ##

    else:
        while answer_yes not in answer and answer_no not in answer:
            print("\nSorry, invalid input")
            print("Please try again!")
            answer = input(prompt="\nDo you want to start the game? \n > ")
            answer = answer.lower()
            if answer_yes in answer:
                prison_cell
            elif answer_no in answer:
                print(f"""\nOkay, Hope you had fun :) \nHave a great day! {name}""")
            else:
                print("Try later!")
